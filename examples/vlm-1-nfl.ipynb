# %% [markdown]
# # Structured extraction over NFL games (and upload to airtable)
#
# In this tutorial, we'll build a flow for 1) extracting info from screenshots of NFL games and 2) uploading that info to a database we will create on Airtable.

# %%
# Install dependencies if needed
# !pip install requests Pillow torch-nos
# Out:
# Requirement already satisfied: requests in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (2.31.0)
# Requirement already satisfied: Pillow in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (10.2.0)
# Requirement already satisfied: torch-nos in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (0.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from requests) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from requests) (2024.2.2)
# Requirement already satisfied: agi-pack>=0.2.0 in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from torch-nos) (0.2.0)
# Requirement already satisfied: cloudpickle>=2.2.1 in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from torch-nos) (3.0.0)
# Requirement already satisfied: docker>=6.0.0 in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from torch-nos) (7.0.0)
# Requirement already satisfied: filelock in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from torch-nos) (3.13.1)
# Requirement already satisfied: gitpython in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from torch-nos) (3.1.42)
# Requirement already satisfied: grpcio-tools<=1.49.1 in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from torch-nos) (1.49.1)
# Requirement already satisfied: humanize in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from torch-nos) (4.9.0)
# Requirement already satisfied: loguru>=0.7.0 in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from torch-nos) (0.7.2)
# Requirement already satisfied: opencv-python-headless>=4.6.0.66 in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from torch-nos) (4.9.0.80)
# Requirement already satisfied: pandas in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from torch-nos) (2.2.1)
# Requirement already satisfied: psutil>=5.9.5 in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from torch-nos) (5.9.8)
# Requirement already satisfied: py-cpuinfo>=9.0.0 in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from torch-nos) (9.0.0)
# Requirement already satisfied: pydantic>=2.5.0 in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from torch-nos) (2.6.3)
# Requirement already satisfied: python-multipart in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from torch-nos) (0.0.9)
# Requirement already satisfied: pyyaml in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from torch-nos) (6.0.1)
# Requirement already satisfied: rich>=12.5.1 in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from torch-nos) (13.7.1)
# Requirement already satisfied: sentry-sdk[loguru] in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from torch-nos) (1.43.0)
# Requirement already satisfied: tqdm in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from torch-nos) (4.66.2)
# Requirement already satisfied: typer>=0.7.0 in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from torch-nos) (0.9.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from torch-nos) (4.10.0)
# Requirement already satisfied: jinja2 in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from agi-pack>=0.2.0->torch-nos) (3.1.3)
# Requirement already satisfied: packaging>=14.0 in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from docker>=6.0.0->torch-nos) (23.2)
# Requirement already satisfied: protobuf<5.0dev,>=4.21.3 in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from grpcio-tools<=1.49.1->torch-nos) (4.25.3)
# Requirement already satisfied: grpcio>=1.49.1 in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from grpcio-tools<=1.49.1->torch-nos) (1.62.1)
# Requirement already satisfied: setuptools in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from grpcio-tools<=1.49.1->torch-nos) (69.2.0)
# Requirement already satisfied: numpy>=1.21.2 in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from opencv-python-headless>=4.6.0.66->torch-nos) (1.26.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from pydantic>=2.5.0->torch-nos) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from pydantic>=2.5.0->torch-nos) (2.16.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from rich>=12.5.1->torch-nos) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from rich>=12.5.1->torch-nos) (2.17.2)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from typer>=0.7.0->torch-nos) (8.1.7)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from gitpython->torch-nos) (4.0.11)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from pandas->torch-nos) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from pandas->torch-nos) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from pandas->torch-nos) (2024.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython->torch-nos) (5.0.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=12.5.1->torch-nos) (0.1.2)
# Requirement already satisfied: six>=1.5 in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->torch-nos) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from jinja2->agi-pack>=0.2.0->torch-nos) (2.1.5)
# Requirement already satisfied: colorama<0.5.0,>=0.4.3 in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from typer[all]->agi-pack>=0.2.0->torch-nos) (0.4.6)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in /Users/scottloftin/dev/miniconda3/envs/vlm/lib/python3.11/site-packages (from typer[all]->agi-pack>=0.2.0->torch-nos) (1.5.4)

# %%
# Set up VLM-1 API.

import os
import requests


VLM_BASE_URL = "https://vlm-dev.nos.run/v1"
response = requests.get(f"{VLM_BASE_URL}/health")
response.raise_for_status()
assert response.status_code == 200

VLM_API_KEY = os.getenv("VLM_API_KEY", None)
if VLM_API_KEY is None:
    VLM_API_KEY = input()
print(f"Using API key: {VLM_API_KEY[:4]}...")

headers = {
    "Content-Type": "application/json",
    "X-API-Key": VLM_API_KEY,
}
response = requests.get(f"{VLM_BASE_URL}/models", headers=headers)
response.raise_for_status()
# Out:
# Using API key: sk-t...

# %%
# %load ../vlm_tools/image.py
import json
from base64 import b64encode
from io import BytesIO
from typing import Literal, Union

import requests
from PIL import Image


def pprint(data):
    print(json.dumps(data, indent=2))


def encode_image(image: Image.Image, format: Literal["PNG", "JPEG"] = "PNG") -> Union[str, bytes]:
    """Convert an image to a base64 string."""
    buffered = BytesIO()
    image_format = image.format or format
    image.save(buffered, format=image_format)
    img_str = b64encode(buffered.getvalue()).decode()
    return f"data:image/{image_format.lower()};base64,{img_str}"


def download_image(url: str) -> Image.Image:
    """Download an image from a URL."""
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:106.0) Gecko/20100101 Firefox/106.0",
        "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8",
    }
    bytes = BytesIO(requests.get(url, headers=headers).content)
    bytes.seek(0)
    return Image.open(bytes).convert("RGB")

# %%
from pathlib import Path
from typing import Union

from PIL import Image
from IPython.display import display


def vlm(image: Image.Image, domain: str):
    """Send an image to the VLM API."""
    data = {
        "model": "vlm-1",
        "domain": domain,
        "image": encode_image(image),
    }
    response = requests.post(f"{VLM_BASE_URL}/generate", headers=headers, json=data)
    response.raise_for_status()
    return response.json()

# %%
# Init our airtable API
import os
from pyairtable import Api

airtable_app_id = os.getenv("AIRTABLE_APP_ID")
airtable_table_name = os.getenv("AIRTABLE_TABLE_NAME")
airtable_auth = os.getenv("AIRTABLE_AUTH_KEY")
print('init airtable with auth key: ', airtable_auth)
airtable_api = Api(api_key=airtable_auth)

# check that we have a base app
base = airtable_api.bases()[0]
print(base.tables()[0].all())

def update_airtable(reponse, airtable_api, table_name):
    # Create the table if it doesn't already exist
    base = airtable_api.bases()[0]
    fields = [] # The schema for the airtable, these are the field names and descriptions that we will populate.
    new_entry = {}
    # Due to limitations in Airtable, we currently only support string entries, so we'll skip recursive fields in this schema
    # and convert any ints to strs.
    for field in reponse.keys():
        if not isinstance(response[field], dict) and not isinstance(response[field], list) and response[field] is not None:
            fields.append({"description": f"Description for {field}", "name": field, "type": "singleLineText"})
            new_entry[field] = str(response[field])
        else:
            print(f"Skipping field {field} because it is a dict or list")

    try:
        print('creating table with fields: ', fields)
        table = base.create_table(table_name, fields)
    except Exception:
        table = base.table(table_name)
        schema_fields= table.schema().fields
        # only update fields that already exist in the table if we didn't just create it:
        table_fields = [field.name for field in schema_fields]
        new_entry = {k: v for k, v in new_entry.items() if k in table_fields}

    print(new_entry)
    table.create(new_entry)
# Out:
# init airtable with auth key:  pat0X1VzA8RSsCf9h.679e5ecd9da6ca6d76e2b97bf112b53b39f98ab9b1de19d9fbf74a766155c135
# base: <Base id='app6mbowPIs3A75BO' name='NFL Play Breakdowns' permission_level='create'>
# [{'id': 'recLsHbpBl1CKLy0H', 'createdTime': '2024-03-12T06:45:09.000Z', 'fields': {'record_id': '4', 'image': [{'id': 'attH1K7JpgdomYHxj', 'width': 420, 'height': 236, 'url': 'https://v5.airtableusercontent.com/v3/u/27/27/1711749600000/111zpGqblIUwjoy8le1PpA/Jmv8UeW_vf-8k2oLM3IqmN76Aa69VekhFe8wx46hMdHQhGxt_1nma2ylUg0Dm3yX2Yp2NNOmW5MLtAVhGbnh2qc-BnPvxTOfqEDJV-UegjW9RKe0sIs_dTHesPqyyhGw9UrB2RQB_vNfKRr_-R1LSQ/TZ1tQOtTr9DhDtRQxnfOnRnXNnDPRCh_HnJpkZO67_w', 'filename': 'sf_kc.webp', 'size': 16550, 'type': 'image/webp', 'thumbnails': {'small': {'url': 'https://v5.airtableusercontent.com/v3/u/27/27/1711749600000/odbAfoSuLpjPcyQxn-cB8g/hlvv3CZ-8TPXu3mOzJkXfjLKqUB1i8_y36x9ygiocp3deRFjy4e-8jKL0U0SIqSxAaFSWEpBNi_ty-ejJDO7fIlPz7XjqblSitJlDIWxe2iXgdWd0gPjgpq6VQquTuA2blfSG3R7-l6eS9EkbfQc3g/wywos26um9QAGjH2UgH0vELcyF4a4ZI1ORdSf3whmtc', 'width': 64, 'height': 36}, 'large': {'url': 'https://v5.airtableusercontent.com/v3/u/27/27/1711749600000/SXdRD61U3rIH8waZunXxDA/YDPLWtZnTBZTTBIzbrtCcB6dtUK2EQzjqkUyRMQa51y4NY3PtCPqFFTMzvKYiNQ2vKOemkKhncssjmIjnMOizanTua1Tu00nZ5a1b9Oqb6_yNH1LyzhRUSRsiYzsMBs9O2tBC9hIgGj55GNDK51eDA/nnEL8vuwskcUUjcSmrP3aIpLZcnsYv-mGmcp3ia2FHM', 'width': 420, 'height': 236}, 'full': {'url': 'https://v5.airtableusercontent.com/v3/u/27/27/1711749600000/8Ytxa7H-E-n37E2N2fVcew/CsA6qShw97uNY-E8XOcZZ_hgkdMyqeC-2XLcWlaUiia0U_R4DzAmEUgN8WCTHCJJjuWvZTyVDLKfEJhn8scP4DS1yUOZzCpOpxg-1bNNfxD2PnSB6COJ9Z2DYxZF6HBCKi-MimSLf5HW5DWiGTxZOA/x7i3IsFm36TGW6XzfIGcFj7mixF70rTDFHegjlv1Zvg', 'width': 420, 'height': 236}}}]}}, {'id': 'recWYiLuAPn8bsnBS', 'createdTime': '2024-03-21T23:25:14.000Z', 'fields': {'record_id': '-1', 'home_team': 'none', 'away_team': 'none', 'network': 'none', 'home_score': 'none', 'away_score': 'none', 'possession_team': 'none', 'quarter': 'none', 'clock_time': 'none', 'down': 'none'}}, {'id': 'receU45FsEYMqseK8', 'createdTime': '2024-03-12T06:45:51.000Z', 'fields': {'record_id': '8', 'image': [{'id': 'attHWWd9JgJWX0mo3', 'width': 1280, 'height': 720, 'url': 'https://v5.airtableusercontent.com/v3/u/27/27/1711749600000/e-u2ZFlEkGmo1eJ1jrZD-A/zaxgl6r8v8wqOx7COg77TxPmZY2F2Eay1kZ1My9qlCpxzgb8hz-oHH0sYmcVb40eYKPKEKLAiosm6eddQdgi73TqWXxNEMNTw3Kb3wmz48krMZ_3cAHzcNRJXHNhPxwW-wuXtqWsDfoCovLAxjuW6g/FjI_e52N5KXiEs0uyw9hCVP1_sFBiQ_koVkAYGxGovQ', 'filename': 'falcons_bucs.jpeg', 'size': 105554, 'type': 'image/jpeg', 'thumbnails': {'small': {'url': 'https://v5.airtableusercontent.com/v3/u/27/27/1711749600000/tfdYZi7Eig2fk1lZQVj3Qw/bcODsZYHrokX19IiJcBPuSe0N43pHmrmdQzvpUdgNxPocQRdXSiDfg5o-37JTXvLcRqZ9epi0xXsjSRR5S1jRU0G2DVRXkPeTCLSBSvQwRKlChH-wEwFjsXllQO9H5esYhx-xciKbQT933FAv9L_cQ/mjdbSjMbB0dmkqOIcQ05jwgNw_nL7FBg4hOpUsaTocw', 'width': 64, 'height': 36}, 'large': {'url': 'https://v5.airtableusercontent.com/v3/u/27/27/1711749600000/5NkRDtafIOPyOgujsVhOqA/O81jyVbeUXuihapJbgRLfftKIfeMGzghhRIdUGIbM5ExBXKU-uGgHtpX6ohY6Xkjj6Mvx_0I_YXeyHPFRUeKLOxLO7QSMFlahbQw30Cm8Giw782uTr9r1EObydNy5zIZmITaig36ai4Hyup-Stg66A/IM0UDMf49xAynJ9j-D9IX4QZwA586rKP7aGz_GCPGGQ', 'width': 910, 'height': 512}, 'full': {'url': 'https://v5.airtableusercontent.com/v3/u/27/27/1711749600000/EnNyH0fKeUHpUNW0cgnFjQ/wxtc4r5dert66rhfu-N6Ge5KuM0435NxxfxQoVK3gFoFu_O5h2iFsn44MWfq-IHfuV3fE0UiyP3E6wC2dAfJkuVbU5Wyfz8vB96_S89seHBOiXz0u4TfB6hVSS3KZ1aQLPUHcU2gHS6KYUrMPov7Ag/RJ-kQ5NYFX9143rVCel6kRoNA6jw8RK2Zwkb9qU5Ci4', 'width': 1280, 'height': 720}}}]}}, {'id': 'rech5f2ixjvS0eiT7', 'createdTime': '2024-03-12T06:45:50.000Z', 'fields': {'record_id': '7', 'image': [{'id': 'attOAm0tE68qcvS06', 'width': 512, 'height': 274, 'url': 'https://v5.airtableusercontent.com/v3/u/27/27/1711749600000/jKgVYDe3kL0rvDvVLVBLCQ/pcaRVjUkuVI0wf8_f-CNc99hs7XEAo7ROE-sTGXZVfcMBIHeKMieLz5tUo6YyJ9HhQPAZE555NXsaNRFPElg8D3J1BzojVEIa-sgWYTcHeOjNjdgsNghd7Mp0umhCZ_Ti2KTPw9xpFqDW0cB9L2f-g/XTTxyYaupo72VSv2Uo0LLiqhUZpXeT6RNH7zUQHGFqw', 'filename': 'bears_titans.png', 'size': 235976, 'type': 'image/png', 'thumbnails': {'small': {'url': 'https://v5.airtableusercontent.com/v3/u/27/27/1711749600000/29fmAOo_tr5YK7uJCj4xbg/FPLR0ba1iiKBGZrw4PH ...

# %%
# Process and visualize a few urls:
URLS = [
    "https://static.www.nfl.com/image/private/t_editorial_landscape_12_desktop/league/osfac1nvcxkjdfa5yhtn",
    "https://i.insider.com/5e24c8ba62fa813a7d022fe3?width=1200&format=jpeg",
    "https://pbs.twimg.com/amplify_video_thumb/1485009987269128195/img/JIIA0Cea5o1LpkHZ.jpg:large",
    "https://static.www.nfl.com/image/private/t_editorial_landscape_12_desktop/league/d33yyhuped2bmobifqoy",
    "https://static.www.nfl.com/image/upload/t_editorial_landscape_12_desktop/league/hid31t8byzxfpz0vtak4",
    "https://cdn-images-1.medium.com/max/800/1*eluBF0MOTAqNCSc4vCEXmQ.png",
    "https://cdn.geekwire.com/wp-content/uploads/2017/12/Screen-Shot-2017-09-28-at-5.50.14-PM-1260x700-630x350.png",
    "https://pbs.twimg.com/amplify_video_thumb/1738699907484065792/img/s-pzq7wLBByXvsuX.jpg",
]

frames = (download_image(_url) for _url in URLS)

for frame in frames:
    response = vlm(frame, domain="sports.nfl")
    pprint(response)
    print(response.keys())
    update_airtable(response, airtable_api, 'nfl_frames_annotated')
# Out:
# {
#   "cls_name": "SportsNFLGameState",
#   "description": "The Dallas Cowboys are playing against the Washington Redskins. The Cowboys are leading with a score of 17 to 13. It is the 3rd quarter with 2 minutes and 27 seconds remaining on the clock. The Redskins have the ball on the 2nd down with 9 yards to go.",
#   "teams": [
#     {
#       "name": "Washington Redskins",
#       "score": 13
#     },
#     {
#       "name": "Dallas Cowboys",
#       "score": 17
#     }
#   ],
#   "status": "in_progress",
#   "quarter": 3,
#   "clock_time": "2:27",
#   "possession_team": "Washington Redskins",
#   "down": "2nd",
#   "distance": 9,
#   "yard_line": null,
#   "network": null,
#   "is_shown": true
# }
# dict_keys(['cls_name', 'description', 'teams', 'status', 'quarter', 'clock_time', 'possession_team', 'down', 'distance', 'yard_line', 'network', 'is_shown'])
# field type:  <class 'str'> field:  cls_name
# set field to string:  SportsNFLGameState
# field type:  <class 'str'> field:  description
# set field to string:  The Dallas Cowboys are playing against the Washington Redskins. The Cowboys are leading with a score of 17 to 13. It is the 3rd quarter with 2 minutes and 27 seconds remaining on the clock. The Redskins have the ball on the 2nd down with 9 yards to go.
# field type:  <class 'list'> field:  teams
# Skipping field teams because it is a dict or list
# field type:  <class 'str'> field:  status
# set field to string:  in_progress
# field type:  <class 'int'> field:  quarter
# set field to string:  3
# field type:  <class 'str'> field:  clock_time
# set field to string:  2:27
# field type:  <class 'str'> field:  possession_team
# set field to string:  Washington Redskins
# field type:  <class 'str'> field:  down
# set field to string:  2nd
# field type:  <class 'int'> field:  distance
# set field to string:  9
# field type:  <class 'NoneType'> field:  yard_line
# Skipping field yard_line because it is a dict or list
# field type:  <class 'NoneType'> field:  network
# Skipping field network because it is a dict or list
# field type:  <class 'bool'> field:  is_shown
# set field to string:  True
# creating table with fields:  [{'description': 'Description for cls_name', 'name': 'cls_name', 'type': 'singleLineText'}, {'description': 'Description for description', 'name': 'description', 'type': 'singleLineText'}, {'description': 'Description for status', 'name': 'status', 'type': 'singleLineText'}, {'description': 'Description for quarter', 'name': 'quarter', 'type': 'singleLineText'}, {'description': 'Description for clock_time', 'name': 'clock_time', 'type': 'singleLineText'}, {'description': 'Description for possession_team', 'name': 'possession_team', 'type': 'singleLineText'}, {'description': 'Description for down', 'name': 'down', 'type': 'singleLineText'}, {'description': 'Description for distance', 'name': 'distance', 'type': 'singleLineText'}, {'description': 'Description for is_shown', 'name': 'is_shown', 'type': 'singleLineText'}]
# Create new entry:
# {'cls_name': 'SportsNFLGameState', 'description': 'The Dallas Cowboys are playing against the Washington Redskins. The Cowboys are leading with a score of 17 to 13. It is the 3rd quarter with 2 minutes and 27 seconds remaining on the clock. The Redskins have the ball on the 2nd down with 9 yards to go.', 'status': 'in_progress', 'quarter': '3', 'clock_time': '2:27', 'possession_team': 'Washington Redskins', 'down': '2nd', 'distance': '9', 'is_shown': 'True'}
# {
#   "cls_name": "SportsNFLGameState",
#   "description": "The image shows a moment from an NFL game where a trick play is being executed. The offense seems to have caught the defense off guard.",
#   "teams": [
#     {
#       "name": "Tennessee Titans",
#       "score": 10
#     },
#     {
#       "name": "Kansas City Chiefs",
#       "score": 7
#     }
#   ],
#   "status": "in_progress",
#   "quarter": 2,
#   "clock_time": "6:41",
#   "possession_team": "Tennessee Titans",
#   "down": "2nd",
#   "distance": "goal",
#   "yard_line": 2,
#   "network": "CBS",
#   "is_shown": true
# }
# dict_keys(['cls_name', 'description', 'teams', 'status', 'quarter', 'clock_time', 'possession_team', 'down', 'distance', 'yard_line', 'network', 'is_shown'])
# field type:  <class 'str'> field:  cls_name
# set field to string:  SportsNFLGameState
# field type:  <class 'str'> field:  description
# set field to string:  The image shows a moment from an NFL game where a trick play is being executed. The offense seems to have caught the defense off guard.
# field type:  <class 'list'> field:  teams
# Skipping field teams because it is a dict or list
# field type:  <class 'str'> field:  status
# set field to string:  in_progress
# field type:  <class 'int'> field:  quarter
# set field to string:  2
# field type:  <class 'str'> field:  clock_time
# set field to string:  6:41
# field type:  <class 'str'> field:  possession_team
# set field to string:  Tennessee Titans
# field type:  <class 'str'> field:  down
# set field to string:  2nd
# field type:  <class 'str'> field:  distance
# set field to string:  goal
# field type:  <class 'int'> field:  yard_line
# set field to string:  2
# field type:  <class 'str'> field:  network
# set field to string:  CBS
# field type:  <class 'bool'> field:  is_shown
# set field to string:  True
# creating table with fields:  [{'description': 'Description for cls_name', 'name': 'cls_name', 'type': 'singleLineText'}, {'description': 'Description for description', 'name': 'description', 'type': 'singleLineText'}, {'description': 'Description for status', 'name': 'status', 'type': 'singleLineText'}, {'description': 'Description for quarter', 'name': 'quarter', 'type': 'singleLineText'}, {'description': 'Description for clock_time', 'name': 'clock_time', 'type': 'singleLineText'}, {'description': 'Description for possession_team', 'name': 'possession_team', 'type': 'singleLineText'}, {'description': 'Description for down', 'name': 'down', 'type': 'singleLineText'}, {'description': 'Description for distance', 'name': 'distance', 'type': 'singleLineText'}, {'description': 'Description for yard_line', 'name': 'yard_line', 'type': 'singleLineText'}, {'description': 'Description for network', 'name': 'network', 'type': 'singleLineText'}, {'description': 'Description for is_shown', 'name': 'is_shown', 'type': 'singleLineText'}]
# Create new entry:
# {'cls_name': 'SportsNFLGameState', 'description': 'The image shows a moment from an NFL game where a trick play is being executed. The offense seems to have caught the defense off guard.', 'status': 'in_progress', 'quarter': '2', 'clock_time': '6:41', 'possession_team': 'Tennessee Titans', 'down': '2nd', 'distance': 'goal', 'is_shown': 'True'}
# {
#   "cls_name": "SportsNFLGameState",
#   "description": "The Cincinnati Bengals are leading with a score of 3 against the Tennessee Titans who have yet to score. The game is in the first quarter with a little over 5 minutes remaining on the clock.",
#   "teams": [
#     {
#       "name": "Cincinnati Bengals",
#       "score": 3
#     },
#     {
#       "name": "Tennessee Titans",
#       "score": 0
#     }
#   ],
#   "status": "in_progress",
#   "quarter": 1,
#   "clock_time": "5:18",
#   "possession_team": "Tennessee Titans",
#   "down": "2nd",
#   "distance": 9,
#   "yard_line": 19,
#   "network": "CBS",
#   "is_shown": true
# }
# dict_keys(['cls_name', 'description', 'teams', 'status', 'quarter', 'clock_time', 'possession_team', 'down', 'distance', 'yard_line', 'network', 'is_shown'])
# field type:  <class 'str'> field:  cls_name
# set field to string:  SportsNFLGameState
# field type:  <class 'str'> field:  description
# set field to string:  The Cincinnati Bengals are leading with a score of 3 against the Tennessee Titans who have yet to score. The game is in the first quarter with a little over 5 minutes remaining on the clock.
# field type:  <class 'list'> field:  teams
# Skipping field teams because it is a dict or list
# field type:  <class 'str'> field:  status
# set field to string:  in_progress
# field type:  <class 'int'> field:  quarter
# set field to string:  1
# field type:  <class 'str'> field:  clock_time
# set field to string:  5:18
# field type:  <class 'str'> field:  possession_team
# set field to string:  Tennessee Titans
# field type:  <class 'str'> field:  down
# set field to string:  2nd
# field type:  <class 'int'> field:  distance
# set field to string:  9
# field type:  <class 'int'> field:  yard_line
# set field to string:  19
# field type:  <class 'str'> field:  network
# set field to string:  CBS
# field type:  <class 'bool'> field:  is_shown
# set field to string:  True
# creating table with fields:  [{'description': 'Description for cls_name', 'name': 'cls_name', 'type': 'singleLineText'}, {'description': 'Description for description', 'name': 'description', 'type': 'singleLineText'}, {'description': 'Description for status', 'name': 'status', 'type': 'singleLineText'}, {'description': 'Description for quarter', 'name': 'quarter', 'type': 'singleLineText'}, {'description': 'Description for clock_time', 'name': 'clock_time', 'type': 'singleLineText'}, {'description': 'Description for possession_team', 'name': 'possession_team', 'type': 'singleLineText'}, {'description': 'Description for down', 'name': 'down', 'type': 'singleLineText'}, {'description': 'Description for distance', 'name': 'distance', 'type': 'singleLineText'}, {'description': 'Description for yard_line', 'name': 'yard_line', 'type': 'singleLineText'}, {'description': 'Description for network', 'name': 'network', 'type': 'singleLineText'}, {'description': 'Description for is_shown', 'name': 'is_shown', 'type': 'singleLineText'}]
# Create new entry:
# {'cls_name': 'SportsNFLGameState', 'description': 'The Cincinnati Bengals are leading with a score of 3 against the Tennessee Titans who have yet to score. The game is in the first quarter with a little over 5 minutes remaining on the clock.', 'status': 'in_progress', 'quarter': '1', 'clock_time': '5:18', 'possession_team': 'Tennessee Titans', 'down': '2nd', 'distance': '9', 'is_shown': 'True'}
# {
#   "cls_name": "SportsNFLGameState",
#   "description": "The New Orleans Saints are leading against the Los Angeles Rams with a score of 38 to 35 in the 4th quarter with 4:03 minutes left on the clock. It is 3rd down with 7 yards to go.",
#   "teams": [
#     {
#       "name": "Los Angeles Rams",
#       "score": 35
#     },
#     {
#       "name": "New Orleans Saints",
#       "score": 38
#     }
#   ],
#   "status": "in_progress",
#   "quarter": 4,
#   "clock_time": "4:03",
#   "possession_team": "New Orleans Saints",
#   "down": "3rd",
#   "distance": 7,
#   "yard_line": 37,
#   "network": null,
#   "is_shown": true
# }
# dict_keys(['cls_name', 'description', 'teams', 'status', 'quarter', 'clock_time', 'possession_team', 'down', 'distance', 'yard_line', 'network', 'is_shown'])
# field type:  <class 'str'> field:  cls_name
# set field to string:  SportsNFLGameState
# field type:  <class 'str'> field:  description
# set field to string:  The New Orleans Saints are leading against the Los Angeles Rams with a score of 38 to 35 in the 4th quarter with 4:03 minutes left on the clock. It is 3rd down with 7 yards to go.
# field type:  <class 'list'> field:  teams
# Skipping field teams because it is a dict or list
# field type:  <class 'str'> field:  status
# set field to string:  in_progress
# field type:  <class 'int'> field:  quarter
# set field to string:  4
# field type:  <class 'str'> field:  clock_time
# set field to string:  4:03
# field type:  <class 'str'> field:  possession_team
# set field to string:  New Orleans Saints
# field type:  <class 'str'> field:  down
# set field to string:  3rd
# field type:  <class 'int'> field:  distance
# set field to string:  7
# field type:  <class 'int'> field:  yard_line
# set field to string:  37
# field type:  <class 'NoneType'> field:  network
# Skipping field network because it is a dict or list
# field type:  <class 'bool'> field:  is_shown
# set field to string:  True
# creating table with fields:  [{'description': 'Description for cls_name', 'name': 'cls_name', 'type': 'singleLineText'}, {'description': 'Description for description', 'name': 'description', 'type': 'singleLineText'}, {'description': 'Description for status', 'name': 'status', 'type': 'singleLineText'}, {'description': 'Description for quarter', 'name': 'quarter', 'type': 'singleLineText'}, {'description': 'Description for clock_time', 'name': 'clock_time', 'type': 'singleLineText'}, {'description': 'Description for possession_team', 'name': 'possession_team', 'type': 'singleLineText'}, {'description': 'Description for down', 'name': 'down', 'type': 'singleLineText'}, {'description': 'Description for distance', 'name': 'distance', 'type': 'singleLineText'}, {'description': 'Description for yard_line', 'name': 'yard_line', 'type': 'singleLineText'}, {'description': 'Description for is_shown', 'name': 'is_shown', 'type': 'singleLineText'}]
# Create new entry:
# {'cls_name': 'SportsNFLGameState', 'description': 'The New Orleans Saints are leading against the Los Angeles Rams with a score of 38 to 35 in the 4th quarter with 4:03 minutes left on the clock. It is 3rd down with 7 yards to go.', 'status': 'in_progress', 'quarter': '4', 'clock_time': '4:03', 'possession_team': 'New Orleans Saints', 'down': '3rd', 'distance': '7', 'is_shown': 'True'}
# {
#   "cls_name": "SportsNFLGameState",
#   "description": "The Atlanta Falcons are leading with a score of 10 against the Jacksonville Jaguars, who have yet to score. The game is in the second quarter with 8 minutes and 36 seconds remaining on the clock. It is 3rd down and 8 yards to go, and the ball is near the 20-yard line.",
#   "teams": [
#     {
#       "name": "Atlanta Falcons",
#       "score": 10
#     },
#     {
#       "name": "Jacksonville Jaguars",
#       "score": 0
#     }
#   ],
#   "status": "in_progress",
#   "quarter": 2,
#   "clock_time": "8:36",
#   "possession_team": "Jacksonville Jaguars",
#   "down": "3rd",
#   "distance": 8,
#   "yard_line": 20,
#   "network": "NFL on ESPN",
#   "is_shown": true
# }
# dict_keys(['cls_name', 'description', 'teams', 'status', 'quarter', 'clock_time', 'possession_team', 'down', 'distance', 'yard_line', 'network', 'is_shown'])
# field type:  <class 'str'> field:  cls_name
# set field to string:  SportsNFLGameState
# field type:  <class 'str'> field:  description
# set field to string:  The Atlanta Falcons are leading with a score of 10 against the Jacksonville Jaguars, who have yet to score. The game is in the second quarter with 8 minutes and 36 seconds remaining on the clock. It is 3rd down and 8 yards to go, and the ball is near the 20-yard line.
# field type:  <class 'list'> field:  teams
# Skipping field teams because it is a dict or list
# field type:  <class 'str'> field:  status
# set field to string:  in_progress
# field type:  <class 'int'> field:  quarter
# set field to string:  2
# field type:  <class 'str'> field:  clock_time
# set field to string:  8:36
# field type:  <class 'str'> field:  possession_team
# set field to string:  Jacksonville Jaguars
# field type:  <class 'str'> field:  down
# set field to string:  3rd
# field type:  <class 'int'> field:  distance
# set field to string:  8
# field type:  <class 'int'> field:  yard_line
# set field to string:  20
# field type:  <class 'str'> field:  network
# set field to string:  NFL on ESPN
# field type:  <class 'bool'> field:  is_shown
# set field to string:  True
# creating table with fields:  [{'description': 'Description for cls_name', 'name': 'cls_name', 'type': 'singleLineText'}, {'description': 'Description for description', 'name': 'description', 'type': 'singleLineText'}, {'description': 'Description for status', 'name': 'status', 'type': 'singleLineText'}, {'description': 'Description for quarter', 'name': 'quarter', 'type': 'singleLineText'}, {'description': 'Description for clock_time', 'name': 'clock_time', 'type': 'singleLineText'}, {'description': 'Description for possession_team', 'name': 'possession_team', 'type': 'singleLineText'}, {'description': 'Description for down', 'name': 'down', 'type': 'singleLineText'}, {'description': 'Description for distance', 'name': 'distance', 'type': 'singleLineText'}, {'description': 'Description for yard_line', 'name': 'yard_line', 'type': 'singleLineText'}, {'description': 'Description for network', 'name': 'network', 'type': 'singleLineText'}, {'description': 'Description for is_shown', 'name': 'is_shown', 'type': 'singleLineText'}]
# Create new entry:
# {'cls_name': 'SportsNFLGameState', 'description': 'The Atlanta Falcons are leading with a score of 10 against the Jacksonville Jaguars, who have yet to score. The game is in the second quarter with 8 minutes and 36 seconds remaining on the clock. It is 3rd down and 8 yards to go, and the ball is near the 20-yard line.', 'status': 'in_progress', 'quarter': '2', 'clock_time': '8:36', 'possession_team': 'Jacksonville Jaguars', 'down': '3rd', 'distance': '8', 'is_shown': 'True'}
# {
#   "cls_name": "SportsNFLGameState",
#   "description": "The Arizona Cardinals are leading against the Green Bay Packers with a score of 7-0 in the second quarter with 12 minutes and 12 seconds remaining. It is 2nd down and 10 yards to go.",
#   "teams": [
#     {
#       "name": "Green Bay Packers",
#       "score": 0
#     },
#     {
#       "name": "Arizona Cardinals",
#       "score": 7
#     }
#   ],
#   "status": "in_progress",
#   "quarter": 2,
#   "clock_time": "12:12",
#   "possession_team": "Green Bay Packers",
#   "down": "2nd",
#   "distance": 10,
#   "yard_line": 40,
#   "network": "NBC",
#   "is_shown": true
# }
# dict_keys(['cls_name', 'description', 'teams', 'status', 'quarter', 'clock_time', 'possession_team', 'down', 'distance', 'yard_line', 'network', 'is_shown'])
# field type:  <class 'str'> field:  cls_name
# set field to string:  SportsNFLGameState
# field type:  <class 'str'> field:  description
# set field to string:  The Arizona Cardinals are leading against the Green Bay Packers with a score of 7-0 in the second quarter with 12 minutes and 12 seconds remaining. It is 2nd down and 10 yards to go.
# field type:  <class 'list'> field:  teams
# Skipping field teams because it is a dict or list
# field type:  <class 'str'> field:  status
# set field to string:  in_progress
# field type:  <class 'int'> field:  quarter
# set field to string:  2
# field type:  <class 'str'> field:  clock_time
# set field to string:  12:12
# field type:  <class 'str'> field:  possession_team
# set field to string:  Green Bay Packers
# field type:  <class 'str'> field:  down
# set field to string:  2nd
# field type:  <class 'int'> field:  distance
# set field to string:  10
# field type:  <class 'int'> field:  yard_line
# set field to string:  40
# field type:  <class 'str'> field:  network
# set field to string:  NBC
# field type:  <class 'bool'> field:  is_shown
# set field to string:  True
# creating table with fields:  [{'description': 'Description for cls_name', 'name': 'cls_name', 'type': 'singleLineText'}, {'description': 'Description for description', 'name': 'description', 'type': 'singleLineText'}, {'description': 'Description for status', 'name': 'status', 'type': 'singleLineText'}, {'description': 'Description for quarter', 'name': 'quarter', 'type': 'singleLineText'}, {'description': 'Description for clock_time', 'name': 'clock_time', 'type': 'singleLineText'}, {'description': 'Description for possession_team', 'name': 'possession_team', 'type': 'singleLineText'}, {'description': 'Description for down', 'name': 'down', 'type': 'singleLineText'}, {'description': 'Description for distance', 'name': 'distance', 'type': 'singleLineText'}, {'description': 'Description for yard_line', 'name': 'yard_line', 'type': 'singleLineText'}, {'description': 'Description for network', 'name': 'network', 'type': 'singleLineText'}, {'description': 'Description for is_shown', 'name': 'is_shown', 'type': 'singleLineText'}]
# Create new entry:
# {'cls_name': 'SportsNFLGameState', 'description': 'The Arizona Cardinals are leading against the Green Bay Packers with a score of 7-0 in the second quarter with 12 minutes and 12 seconds remaining. It is 2nd down and 10 yards to go.', 'status': 'in_progress', 'quarter': '2', 'clock_time': '12:12', 'possession_team': 'Green Bay Packers', 'down': '2nd', 'distance': '10', 'is_shown': 'True'}
# {
#   "cls_name": "SportsNFLGameState",
#   "description": "The Green Bay Packers are leading against the Chicago Bears with a score of 14 to 0. It's the first quarter with 8 minutes and 49 seconds remaining on the clock. The Bears have possession and are facing a 1st and 10 situation.",
#   "teams": [
#     {
#       "name": "Chicago Bears",
#       "score": 0
#     },
#     {
#       "name": "Green Bay Packers",
#       "score": 14
#     }
#   ],
#   "status": "in_progress",
#   "quarter": 1,
#   "clock_time": "8:49",
#   "possession_team": "Chicago Bears",
#   "down": "1st",
#   "distance": 10,
#   "yard_line": 20,
#   "network": "CBS",
#   "is_shown": true
# }
# dict_keys(['cls_name', 'description', 'teams', 'status', 'quarter', 'clock_time', 'possession_team', 'down', 'distance', 'yard_line', 'network', 'is_shown'])
# field type:  <class 'str'> field:  cls_name
# set field to string:  SportsNFLGameState
# field type:  <class 'str'> field:  description
# set field to string:  The Green Bay Packers are leading against the Chicago Bears with a score of 14 to 0. It's the first quarter with 8 minutes and 49 seconds remaining on the clock. The Bears have possession and are facing a 1st and 10 situation.
# field type:  <class 'list'> field:  teams
# Skipping field teams because it is a dict or list
# field type:  <class 'str'> field:  status
# set field to string:  in_progress
# field type:  <class 'int'> field:  quarter
# set field to string:  1
# field type:  <class 'str'> field:  clock_time
# set field to string:  8:49
# field type:  <class 'str'> field:  possession_team
# set field to string:  Chicago Bears
# field type:  <class 'str'> field:  down
# set field to string:  1st
# field type:  <class 'int'> field:  distance
# set field to string:  10
# field type:  <class 'int'> field:  yard_line
# set field to string:  20
# field type:  <class 'str'> field:  network
# set field to string:  CBS
# field type:  <class 'bool'> field:  is_shown
# set field to string:  True
# creating table with fields:  [{'description': 'Description for cls_name', 'name': 'cls_name', 'type': 'singleLineText'}, {'description': 'Description for description', 'name': 'description', 'type': 'singleLineText'}, {'description': 'Description for status', 'name': 'status', 'type': 'singleLineText'}, {'description': 'Description for quarter', 'name': 'quarter', 'type': 'singleLineText'}, {'description': 'Description for clock_time', 'name': 'clock_time', 'type': 'singleLineText'}, {'description': 'Description for possession_team', 'name': 'possession_team', 'type': 'singleLineText'}, {'description': 'Description for down', 'name': 'down', 'type': 'singleLineText'}, {'description': 'Description for distance', 'name': 'distance', 'type': 'singleLineText'}, {'description': 'Description for yard_line', 'name': 'yard_line', 'type': 'singleLineText'}, {'description': 'Description for network', 'name': 'network', 'type': 'singleLineText'}, {'description': 'Description for is_shown', 'name': 'is_shown', 'type': 'singleLineText'}]
# Create new entry:
# {'cls_name': 'SportsNFLGameState', 'description': "The Green Bay Packers are leading against the Chicago Bears with a score of 14 to 0. It's the first quarter with 8 minutes and 49 seconds remaining on the clock. The Bears have possession and are facing a 1st and 10 situation.", 'status': 'in_progress', 'quarter': '1', 'clock_time': '8:49', 'possession_team': 'Chicago Bears', 'down': '1st', 'distance': '10', 'is_shown': 'True'}
# {
#   "cls_name": "SportsNFLGameState",
#   "description": "The Pittsburgh Steelers are leading the Cincinnati Bengals with a score of 24 to 0 in the 3rd quarter.",
#   "teams": [
#     {
#       "name": "Cincinnati Bengals",
#       "score": 0
#     },
#     {
#       "name": "Pittsburgh Steelers",
#       "score": 24
#     }
#   ],
#   "status": "in_progress",
#   "quarter": 3,
#   "clock_time": "11:21",
#   "possession_team": "Cincinnati Bengals",
#   "down": "1st",
#   "distance": 10,
#   "yard_line": 24,
#   "network": "Steelers",
#   "is_shown": true
# }
# dict_keys(['cls_name', 'description', 'teams', 'status', 'quarter', 'clock_time', 'possession_team', 'down', 'distance', 'yard_line', 'network', 'is_shown'])
# field type:  <class 'str'> field:  cls_name
# set field to string:  SportsNFLGameState
# field type:  <class 'str'> field:  description
# set field to string:  The Pittsburgh Steelers are leading the Cincinnati Bengals with a score of 24 to 0 in the 3rd quarter.
# field type:  <class 'list'> field:  teams
# Skipping field teams because it is a dict or list
# field type:  <class 'str'> field:  status
# set field to string:  in_progress
# field type:  <class 'int'> field:  quarter
# set field to string:  3
# field type:  <class 'str'> field:  clock_time
# set field to string:  11:21
# field type:  <class 'str'> field:  possession_team
# set field to string:  Cincinnati Bengals
# field type:  <class 'str'> field:  down
# set field to string:  1st
# field type:  <class 'int'> field:  distance
# set field to string:  10
# field type:  <class 'int'> field:  yard_line
# set field to string:  24
# field type:  <class 'str'> field:  network
# set field to string:  Steelers
# field type:  <class 'bool'> field:  is_shown
# set field to string:  True
# creating table with fields:  [{'description': 'Description for cls_name', 'name': 'cls_name', 'type': 'singleLineText'}, {'description': 'Description for description', 'name': 'description', 'type': 'singleLineText'}, {'description': 'Description for status', 'name': 'status', 'type': 'singleLineText'}, {'description': 'Description for quarter', 'name': 'quarter', 'type': 'singleLineText'}, {'description': 'Description for clock_time', 'name': 'clock_time', 'type': 'singleLineText'}, {'description': 'Description for possession_team', 'name': 'possession_team', 'type': 'singleLineText'}, {'description': 'Description for down', 'name': 'down', 'type': 'singleLineText'}, {'description': 'Description for distance', 'name': 'distance', 'type': 'singleLineText'}, {'description': 'Description for yard_line', 'name': 'yard_line', 'type': 'singleLineText'}, {'description': 'Description for network', 'name': 'network', 'type': 'singleLineText'}, {'description': 'Description for is_shown', 'name': 'is_shown', 'type': 'singleLineText'}]
# Create new entry:
# {'cls_name': 'SportsNFLGameState', 'description': 'The Pittsburgh Steelers are leading the Cincinnati Bengals with a score of 24 to 0 in the 3rd quarter.', 'status': 'in_progress', 'quarter': '3', 'clock_time': '11:21', 'possession_team': 'Cincinnati Bengals', 'down': '1st', 'distance': '10', 'is_shown': 'True'}
